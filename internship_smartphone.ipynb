# %% [markdown]
# # Rank Features of a Smartphone - Build a Python Application to Classify and Rank Dataset.

# %% [markdown]
# Attributes of Smartphone

# %% [markdown]
# 	battery_power: Total energy a battery can store in one time measured in mAh
# 	blue: Has Bluetooth or not
# 	clock_speed: the speed at which microprocessor executes instructions
# 	dual_sim: Has dual sim support or not
# 	fc: Front Camera megapixels
# 	four_g: Has 4G or not
# 	int_memory: Internal Memory in Gigabytes
# 	m_dep: Mobile Depth in cm
# 	mobile_wt: Weight of mobile phone
# 	n_cores: Number of cores of the processor
# 	pc: Primary Camera megapixels
# 	px_height: Pixel Resolution Height
# 	px_width: Pixel Resolution Width
# 	ram: Random Access Memory in MegaBytes
# 	sc_h: Screen Height of mobile in cm
# 	sc_w: Screen Width of mobile in cm
# 	talk_time: the longest time that a single battery charge will last when you are constantly talking on the phone
# 	three_g: Has 3G or not
# 	touch_screen: Has touch screen or not
# 	wifi: Has wifi or not
# 	price_range: This is the target variable with a value of 0(low cost), 1(medium cost), 2(high cost) and 3(very high cost).

# %%
# Importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To filter/truncate warnings
import warnings
warnings.filterwarnings('ignore')

#To see maximum no of columns
pd.pandas.set_option('display.max_columns',None)

# %%
# Reading the train dataset
df_train = pd.read_csv('MobileTrain.csv')

# Reading the test dataset
df_test = pd.read_csv('MobileTest.csv')

# %%
# Display first 5 rows of train data
df_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1

# %%
# Display first 5 rows of test data
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1

# %%
#Dimensions of dataset
df_train.shape,df_test.shape
# Out:
# ((2000, 21), (1000, 21))

# %%
#The train data contains 2000 rows and 21 columns

#The test dataset contains 1000 rows and 21 columns

#price_range is the Target variable

# %%
df_train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
#Basic information about the train dataset
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
#  18  three_g        1000 non-null   int64
#  19  touch_screen   1000 non-null   int64
#  20  wifi           1000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 164.2 KB

# %%
# Statistical information about the dataset
df_train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# min       0.000000     2.000000     0.100000    80.000000     1.000000
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000
# max       1.000000    64.000000     1.000000   200.000000     8.000000
#
#                 pc    px_height     px_width          ram         sc_h  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      9.916500   645.108000  1251.515500  2124.213000    12.306500
# std       6.064315   443.780811   432.199447  1084.732044     4.213245
# min       0.000000     0.000000   500.000000   256.000000     5.000000
# 25%       5.000000   282.750000   874.750000  1207.500000     9.000000
# 50%      10.000000   564.000000  1247.000000  2146.500000    12.000000
# 75%      15.000000   947.250000  1633.000000  3064.500000    16.000000
# max      20.000000  1960.000000  1998.000000  3998.000000    19.000000
#
#               sc_w    talk_time      three_g  touch_screen         wifi  \
# count  2000.000000  2000.000000  2000.000000   2000.000000  2000.000000
# mean      5.767000    11.011000     0.761500      0.503000     0.507000
# std       4.356398     5.463955     0.426273      0.500116     0.500076
# min       0.000000     2.000000     0.000000      0.000000     0.000000
# 25%       2.000000     6.000000     1.000000      0.000000     0.000000
# 50%       5.000000    11.000000     1.000000      1.000000     1.000000
# 75%       9.000000    16.000000     1.000000      1.000000     1.000000
# max      18.000000    20.000000     1.000000      1.000000     1.000000
#
#        price_range
# count  2000.000000
# mean      1.500000
# std       1.118314
# min       0.000000
# 25%       0.750000
# 50%       1.500000
# 75%       2.250000
# max       3.000000

# %%
df_test.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean      4.593000     0.487000    33.652000     0.517500   139.51100
# std       4.463325     0.500081    18.128694     0.280861    34.85155
# min       0.000000     0.000000     2.000000     0.100000    80.00000
# 25%       1.000000     0.000000    18.000000     0.300000   109.75000
# 50%       3.000000     0.000000    34.500000     0.500000   139.00000
# 75%       7.000000     1.000000    49.000000     0.800000   170.00000
# max      19.000000     1.000000    64.000000     1.000000   200.00000
#
#            n_cores           pc    px_height     px_width          ram  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      4.328000    10.054000   627.121000  1239.774000  2138.998000
# std       2.288155     6.095099   432.929699   439.670981  1088.092278
# min       1.000000     0.000000     0.000000   501.000000   263.000000
# 25%       2.000000     5.000000   263.750000   831.750000  1237.250000
# 50%       4.000000    10.000000   564.500000  1250.000000  2153.500000
# 75%       6.000000    16.000000   903.000000  1637.750000  3065.500000
# max       8.000000    20.000000  1907.000000  1998.000000  3989.000000
#
#               sc_h         sc_w    talk_time      three_g  touch_screen  \
# count  1000.000000  1000.000000  1000.000000  1000.000000    1000.00000
# mean     11.995000     5.316000    11.085000     0.756000       0.50000
# std       4.320607     4.240062     5.497636     0.429708       0.50025
# min       5.000000     0.000000     2.000000     0.000000       0.00000
# 25%       8.000000     2.000000     6.750000     1.000000       0.00000
# 50%      12.000000     5.000000    11.000000     1.000000       0.50000
# 75%      16.000000     8.000000    16.000000     1.000000       1.00000
# max      19.000000    18.000000    20.000000     1.000000       1.00000
#
#               wifi
# count  1000.000000
# mean      0.507000
# std       0.500201
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df_train.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
df_test.dtypes
# Out:
# id                 int64
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# dtype: object

# %%
#The train and test data does not contain any categorical values.All values are numerical type.

# %%
# Checking null values in train dataset
df_train.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# Checking null values in test dataset
df_test.isnull().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
# There are no null values present in train and test dataset.

# %%
#Number of unique values
df_train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
df_test.nunique()
# Out:
# id               1000
# battery_power     721
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height         694
# px_width          743
# ram               872
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# dtype: int64

# %% [markdown]
# # EDA - Univariate analysis of Numerical features

# %%
# Histogram to check the distribution of all the numerical columns
df_train.select_dtypes(include=['int64','float64']).hist(figsize = (15,20))
plt.show()

# %%
# CountPlot for various columns
for i in df_train:
    if(df_train[i].nunique()<30):
        sns.countplot(x=df_train[i])
        plt.show()

# %%
#Analysis based on Percentages using Pie Chart

#bluetooth devices

count=df_train["blue"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having BlueTooth")
plt.show()

# %% [markdown]
# 50.50% smartphones sold have BlueTooth and 49.50% doesn't have it.

# %%
#dual sim

count=df_train["dual_sim"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having dual sim")
plt.show()

# %% [markdown]
# 50.95% smartphones sold have dual sim and 49.05% doesn't have it.

# %%
#4G
count=df_train["four_g"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having 4G connection")
plt.show()

# %% [markdown]
# 52.15% smartphones have 4G connection and 47.85% doesn't have it.

# %%
#3G

count=df_train["three_g"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having 3G connection")
plt.show()

# %% [markdown]
# 76.15% smartphones have 3G connection and 23.85% doesn't have it.

# %%
#Touch Screen
count=df_train["touch_screen"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having Touch Screen")
plt.show()

# %% [markdown]
# 50.30% smartphones sold have Touch screen and 49.70% doesn't have it.

# %%
#Wifi
count=df_train["wifi"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having Wifi")
plt.show()

# %% [markdown]
# 50.70% of the smartphones sold have wifi and 49.30% doesn't have it.

# %%
#Processors
count=df_train["n_cores"].value_counts()
plt.figure(figsize=(5,5))
plt.pie(count,labels=count.index,autopct='%1.2f%%')
plt.title("Percentage of devices having different number of Cores")
plt.show()

# %% [markdown]
# Smartphones with Quad Core are the most sought after.

# %%
#Distplot for various columns
plt.figure(figsize = (30,10))
plt.subplot(331)
sns.distplot(df_train['battery_power'])
plt.subplot(332)
sns.distplot(df_train['clock_speed'])
plt.subplot(333)
sns.distplot(df_train['int_memory'])
plt.subplot(334)
sns.distplot(df_train['m_dep'])
plt.subplot(335)
sns.distplot(df_train['mobile_wt'])
plt.subplot(336)
sns.distplot(df_train['px_height'])
plt.subplot(337)
sns.distplot(df_train['px_width'])
plt.subplot(338)
sns.distplot(df_train['ram'])
plt.subplot(339)
sns.distplot(df_train['talk_time'])
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#Analysis on numerical data
plt.figure(figsize=(20,15))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %% [markdown]
# ram is highly correlated with price range followed by battery power, pixel height and width, while m_dep, clock_speed and n_cores seems to be least correlated with price_range.

# %%
# Bivariate Analysis on features

# %%
plt.figure()
sns.barplot(y="ram", x="price_range", data=df_train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='ram'>

# %%
plt.figure()
sns.barplot(y="int_memory", x="price_range", data=df_train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='int_memory'>

# %%
plt.figure()
sns.barplot(y="battery_power", x="price_range", data=df_train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %%
plt.figure()
sns.barplot(y="touch_screen", x="price_range", data=df_train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='touch_screen'>

# %%
plt.figure()
sns.barplot(y="px_width", x="price_range", data=df_train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='px_width'>

# %% [markdown]
# # Outlier detection

# %%
fig,axes = plt.subplots(5,3,figsize = (16,18))
sns.boxplot(x=df_train['battery_power'],ax=axes[0,0])
sns.boxplot( x=df_train['clock_speed'],ax=axes[0,1])
sns.boxplot( x= df_train['fc'],ax=axes[0,2])
sns.boxplot( x=df_train['int_memory'],ax=axes[1,0])
sns.boxplot( x=df_train['m_dep'],ax=axes[1,1])
sns.boxplot( x=df_train['mobile_wt'],ax=axes[1,2])
sns.boxplot( x=df_train['pc'],ax=axes[2,0])
sns.boxplot( x=df_train['px_height'],ax=axes[2,1])
sns.boxplot( x=df_train['px_width'],ax=axes[2,2])
sns.boxplot( x=df_train['ram'],ax=axes[3,0])
sns.boxplot( x=df_train['sc_h'],ax=axes[3,1])
sns.boxplot( x=df_train['sc_w'],ax=axes[3,2])
sns.boxplot(x=df_train['n_cores'],ax=axes[4,0])
sns.boxplot(x=df_train['talk_time'],ax=axes[4,1])

plt.show()

# %%
#There are only few outliers in the dataset.Hence no need to remove those outliers.

# %% [markdown]
# # Classify the datset into software and hardware

# %%
df1 = df_train.loc[:,['battery_power','blue','four_g','mobile_wt','n_cores','px_height','px_width','price_range','talk_time','three_g','wifi','clock_speed']]
df1
# Out:
#       battery_power  blue  four_g  mobile_wt  n_cores  px_height  px_width  \
# 0               842     0       0        188        2         20       756
# 1              1021     1       1        136        3        905      1988
# 2               563     1       1        145        5       1263      1716
# 3               615     1       0        131        6       1216      1786
# 4              1821     1       1        141        2       1208      1212
# ...             ...   ...     ...        ...      ...        ...       ...
# 1995            794     1       1        106        6       1222      1890
# 1996           1965     1       0        187        4        915      1965
# 1997           1911     0       1        108        8        868      1632
# 1998           1512     0       1        145        5        336       670
# 1999            510     1       1        168        6        483       754
#
#       price_range  talk_time  three_g  wifi  clock_speed
# 0               1         19        0     1          2.2
# 1               2          7        1     0          0.5
# 2               2          9        1     0          0.5
# 3               2         11        1     0          2.5
# 4               1         15        1     0          1.2
# ...           ...        ...      ...   ...          ...
# 1995            0         19        1     0          0.5
# 1996            2         16        1     1          2.6
# 1997            3          5        1     0          0.9
# 1998            0         19        1     1          0.9
# 1999            3          2        1     1          2.0
#
# [2000 rows x 12 columns]

# %%
df2 = df_train.loc[:,['dual_sim','fc','m_dep','int_memory','pc','ram','sc_h','sc_w','touch_screen']]
df2
# Out:
#       dual_sim  fc  m_dep  int_memory  pc   ram  sc_h  sc_w  touch_screen
# 0            0   1    0.6           7   2  2549     9     7             0
# 1            1   0    0.7          53   6  2631    17     3             1
# 2            1   2    0.9          41   6  2603    11     2             1
# 3            0   0    0.8          10   9  2769    16     8             0
# 4            0  13    0.6          44  14  1411     8     2             1
# ...        ...  ..    ...         ...  ..   ...   ...   ...           ...
# 1995         1   0    0.8           2  14   668    13     4             1
# 1996         1   0    0.2          39   3  2032    11    10             1
# 1997         1   1    0.7          36   3  3057     9     1             1
# 1998         0   4    0.1          46   5   869    18    10             1
# 1999         1   5    0.9          45  16  3919    19     4             1
#
# [2000 rows x 9 columns]

# %%
#Merging Datasets

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#       battery_power  blue  four_g  mobile_wt  n_cores  px_height  px_width  \
# 0               842     0       0        188        2         20       756
# 1              1021     1       1        136        3        905      1988
# 2               563     1       1        145        5       1263      1716
# 3               615     1       0        131        6       1216      1786
# 4              1821     1       1        141        2       1208      1212
# ...             ...   ...     ...        ...      ...        ...       ...
# 1995            794     1       1        106        6       1222      1890
# 1996           1965     1       0        187        4        915      1965
# 1997           1911     0       1        108        8        868      1632
# 1998           1512     0       1        145        5        336       670
# 1999            510     1       1        168        6        483       754
#
#       price_range  talk_time  three_g  wifi  clock_speed  dual_sim  fc  m_dep  \
# 0               1         19        0     1          2.2         0   1    0.6
# 1               2          7        1     0          0.5         1   0    0.7
# 2               2          9        1     0          0.5         1   2    0.9
# 3               2         11        1     0          2.5         0   0    0.8
# 4               1         15        1     0          1.2         0  13    0.6
# ...           ...        ...      ...   ...          ...       ...  ..    ...
# 1995            0         19        1     0          0.5         1   0    0.8
# 1996            2         16        1     1          2.6         1   0    0.2
# 1997            3          5        1     0          0.9         1   1    0.7
# 1998            0         19        1     1          0.9         0   4    0.1
# 1999            3          2        1     1          2.0         1   5    0.9
#
#       int_memory  pc   ram  sc_h  sc_w  touch_screen
# 0              7   2  2549     9     7             0
# 1             53   6  2631    17     3             1
# 2             41   6  2603    11     2             1
# 3             10   9  2769    16     8             0
# 4             44  14  1411     8     2             1
# ...          ...  ..   ...   ...   ...           ...
# 1995           2  14   668    13     4             1
# 1996          39   3  2032    11    10             1
# 1997          36   3  3057     9     1             1
# 1998          46   5   869    18    10             1
# 1999          45  16  3919    19     4             1
#
# [2000 rows x 21 columns]

# %%
X=df_train.drop(['price_range'],axis=1)
y=df_train['price_range']

# %%
# Feature selection

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

#apply SelectKBest class to extract top 12 best features
bestfeatures = SelectKBest(score_func=chi2, k=12)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  #naming the dataframe columns
print(featureScores.nlargest(12,'Score'))  #print 12 best features
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878
# 10             pc       9.186054
# 9         n_cores       9.097556

# %%
#Feature importance

from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
ranked_features = pd.Series(model.feature_importances_, index=X.columns)
ranked_features.nlargest(12).plot(kind='barh')
plt.show()
# Out:
# [0.06156003 0.02022142 0.03385563 0.01940173 0.03212311 0.01642012
#  0.03555188 0.03372517 0.03717579 0.03276412 0.03428757 0.04808211
#  0.04667303 0.39170571 0.03401046 0.03488699 0.03469553 0.01468437
#  0.01829799 0.01987726]

# %%
#Feature reduction
corrmatrix = df_train.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmatrix,vmin=-0.7,vmax=0.8,annot=True,linewidths = 0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Scaling

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

X=df_train.drop("price_range", axis=1)
y=df_train["price_range"]

#scaler= StandardScaler()
#X=scaler.fit_transform(X)
#X=pd.DataFrame(X)
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_train_scaled=scaler.fit_transform(X)
df_train_scaled=pd.DataFrame(df_train_scaled)
df_train_scaled.describe()
# Out:
#                  0             1             2             3             4   \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean   2.128298e-16 -1.927347e-16 -2.172151e-16  3.990142e-16  9.230117e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.678817e+00 -9.900495e-01 -1.253064e+00 -1.019184e+00 -9.928904e-01
# 25%   -8.804033e-01 -9.900495e-01 -1.007906e+00 -1.019184e+00 -7.624947e-01
# 50%   -2.849593e-02 -9.900495e-01 -2.727384e-02  9.811771e-01 -3.017032e-01
# 75%    8.575560e-01  1.010051e+00  8.307794e-01  9.811771e-01  6.198797e-01
# max    1.728812e+00  1.010051e+00  1.811412e+00  9.811771e-01  3.384628e+00
#
#                  5             6             7             8             9   \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean  -2.048361e-16 -8.754109e-17 -1.045830e-16  1.804112e-16 -4.690692e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.043966e+00 -1.656260e+00 -1.393304e+00 -1.702391e+00 -1.539175e+00
# 25%   -1.043966e+00 -8.845346e-01 -1.046495e+00 -8.829695e-01 -6.647678e-01
# 50%    9.578860e-01 -2.563229e-03 -6.069151e-03  2.122020e-02 -2.275644e-01
# 75%    9.578860e-01  8.794082e-01  1.034357e+00  8.406421e-01  1.084046e+00
# max    9.578860e-01  1.761380e+00  1.727974e+00  1.688320e+00  1.521249e+00
#
#                  10            11            12            13            14  \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean   1.669775e-16  1.287304e-16  5.595524e-17 -1.582068e-16  3.719247e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.635631e+00 -1.454027e+00 -1.739251e+00 -1.722711e+00 -1.734608e+00
# 25%   -8.109291e-01 -8.167289e-01 -8.719579e-01 -8.453168e-01 -7.849833e-01
# 50%    1.377252e-02 -1.828116e-01 -1.045034e-02  2.055123e-02 -7.276497e-02
# 75%    8.384742e-01  6.810064e-01  8.828792e-01  8.670548e-01  8.768595e-01
# max    1.663176e+00  2.963672e+00  1.727608e+00  1.727851e+00  1.589078e+00
#
#                  15            16            17            18            19
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean  -4.085621e-17  1.052491e-16  2.184919e-16  3.065326e-16  4.278800e-16
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.324131e+00 -1.649584e+00 -1.786861e+00 -1.006018e+00 -1.014099e+00
# 25%   -8.649215e-01 -9.173306e-01  5.596406e-01 -1.006018e+00 -1.014099e+00
# 50%   -1.761069e-01 -2.013697e-03  5.596406e-01  9.940179e-01  9.860966e-01
# 75%    7.423125e-01  9.133032e-01  5.596406e-01  9.940179e-01  9.860966e-01
# max    2.808756e+00  1.645557e+00  5.596406e-01  9.940179e-01  9.860966e-01

# %%
#X.describe()
# Out:
#                  0             1             2             3             4   \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean   2.128298e-16 -1.927347e-16 -2.172151e-16  3.990142e-16  9.230117e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.678817e+00 -9.900495e-01 -1.253064e+00 -1.019184e+00 -9.928904e-01
# 25%   -8.804033e-01 -9.900495e-01 -1.007906e+00 -1.019184e+00 -7.624947e-01
# 50%   -2.849593e-02 -9.900495e-01 -2.727384e-02  9.811771e-01 -3.017032e-01
# 75%    8.575560e-01  1.010051e+00  8.307794e-01  9.811771e-01  6.198797e-01
# max    1.728812e+00  1.010051e+00  1.811412e+00  9.811771e-01  3.384628e+00
#
#                  5             6             7             8             9   \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean  -2.048361e-16 -8.754109e-17 -1.045830e-16  1.804112e-16 -4.690692e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.043966e+00 -1.656260e+00 -1.393304e+00 -1.702391e+00 -1.539175e+00
# 25%   -1.043966e+00 -8.845346e-01 -1.046495e+00 -8.829695e-01 -6.647678e-01
# 50%    9.578860e-01 -2.563229e-03 -6.069151e-03  2.122020e-02 -2.275644e-01
# 75%    9.578860e-01  8.794082e-01  1.034357e+00  8.406421e-01  1.084046e+00
# max    9.578860e-01  1.761380e+00  1.727974e+00  1.688320e+00  1.521249e+00
#
#                  10            11            12            13            14  \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean   1.669775e-16  1.287304e-16  5.595524e-17 -1.582068e-16  3.719247e-17
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.635631e+00 -1.454027e+00 -1.739251e+00 -1.722711e+00 -1.734608e+00
# 25%   -8.109291e-01 -8.167289e-01 -8.719579e-01 -8.453168e-01 -7.849833e-01
# 50%    1.377252e-02 -1.828116e-01 -1.045034e-02  2.055123e-02 -7.276497e-02
# 75%    8.384742e-01  6.810064e-01  8.828792e-01  8.670548e-01  8.768595e-01
# max    1.663176e+00  2.963672e+00  1.727608e+00  1.727851e+00  1.589078e+00
#
#                  15            16            17            18            19
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean  -4.085621e-17  1.052491e-16  2.184919e-16  3.065326e-16  4.278800e-16
# std    1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min   -1.324131e+00 -1.649584e+00 -1.786861e+00 -1.006018e+00 -1.014099e+00
# 25%   -8.649215e-01 -9.173306e-01  5.596406e-01 -1.006018e+00 -1.014099e+00
# 50%   -1.761069e-01 -2.013697e-03  5.596406e-01  9.940179e-01  9.860966e-01
# 75%    7.423125e-01  9.133032e-01  5.596406e-01  9.940179e-01  9.860966e-01
# max    2.808756e+00  1.645557e+00  5.596406e-01  9.940179e-01  9.860966e-01

# %% [markdown]
# # Splitting of dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
print('X_train:',X_train.shape)
print('X_test:',X_test.shape)
print('y_train:',y_train.shape)
print('y_test:',y_test.shape)
# Out:
# X_train: (1500, 20)
# X_test: (500, 20)
# y_train: (1500,)
# y_test: (500,)

# %% [markdown]
# # Modelling

# %%
y=df_train["price_range"]
y.value_counts(normalize=True)
# Out:
# 1    0.25
# 2    0.25
# 3    0.25
# 0    0.25
# Name: price_range, dtype: float64

# %%
sns.countplot(y)
plt.title("price_range")
plt.show()

# %% [markdown]
# Target column price_range is balanced

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit_model= LogisticRegression()
logit_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logit_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report,precision_score, recall_score, f1_score
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("Results from Logistic Regression ")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# Accuracy is: 0.962
# Results from Logistic Regression
# <style type="text/css">
# #T_3af1c_row0_col0 {
#   background-color: #016e5e;
#   color: #f1f1f1;
# }
# #T_3af1c_row0_col1, #T_3af1c_row3_col0, #T_3af1c_row3_col2, #T_3af1c_row5_col3, #T_3af1c_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_3af1c_row0_col2 {
#   background-color: #015745;
#   color: #f1f1f1;
# }
# #T_3af1c_row0_col3 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_3af1c_row1_col0 {
#   background-color: #ece2f0;
#   color: #000000;
# }
# #T_3af1c_row1_col1, #T_3af1c_row1_col2, #T_3af1c_row2_col0, #T_3af1c_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3af1c_row1_col3 {
#   background-color: #d8d6e9;
#   color: #000000;
# }
# #T_3af1c_row2_col1 {
#   background-color: #4e9cc7;
#   color: #f1f1f1;
# }
# #T_3af1c_row2_col2 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_3af1c_row2_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_3af1c_row3_col1 {
#   background-color: #016350;
#   color: #f1f1f1;
# }
# #T_3af1c_row3_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_3af1c_row4_col0 {
#   background-color: #5da4cc;
#   color: #f1f1f1;
# }
# #T_3af1c_row4_col1, #T_3af1c_row6_col1 {
#   background-color: #2d8db6;
#   color: #f1f1f1;
# }
# #T_3af1c_row4_col2 {
#   background-color: #519ec8;
#   color: #f1f1f1;
# }
# #T_3af1c_row5_col0 {
#   background-color: #68a9cf;
#   color: #f1f1f1;
# }
# #T_3af1c_row5_col1 {
#   background-color: #3a92c1;
#   color: #f1f1f1;
# }
# #T_3af1c_row5_col2 {
#   background-color: #5fa5cc;
#   color: #f1f1f1;
# }
# #T_3af1c_row6_col0 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_3af1c_row6_col2 {
#   background-color: #4f9dc8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3af1c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3af1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3af1c_row0_col0" class="data row0 col0" >0.983871</td>
#       <td id="T_3af1c_row0_col1" class="data row0 col1" >0.976000</td>
#       <td id="T_3af1c_row0_col2" class="data row0 col2" >0.979920</td>
#       <td id="T_3af1c_row0_col3" class="data row0 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3af1c_row1_col0" class="data row1 col0" >0.936364</td>
#       <td id="T_3af1c_row1_col1" class="data row1 col1" >0.936364</td>
#       <td id="T_3af1c_row1_col2" class="data row1 col2" >0.936364</td>
#       <td id="T_3af1c_row1_col3" class="data row1 col3" >110.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3af1c_row2_col0" class="data row2 col0" >0.928000</td>
#       <td id="T_3af1c_row2_col1" class="data row2 col1" >0.958678</td>
#       <td id="T_3af1c_row2_col2" class="data row2 col2" >0.943089</td>
#       <td id="T_3af1c_row2_col3" class="data row2 col3" >121.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3af1c_row3_col0" class="data row3 col0" >0.992908</td>
#       <td id="T_3af1c_row3_col1" class="data row3 col1" >0.972222</td>
#       <td id="T_3af1c_row3_col2" class="data row3 col2" >0.982456</td>
#       <td id="T_3af1c_row3_col3" class="data row3 col3" >144.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_3af1c_row4_col0" class="data row4 col0" >0.962000</td>
#       <td id="T_3af1c_row4_col1" class="data row4 col1" >0.962000</td>
#       <td id="T_3af1c_row4_col2" class="data row4 col2" >0.962000</td>
#       <td id="T_3af1c_row4_col3" class="data row4 col3" >0.962000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_3af1c_row5_col0" class="data row5 col0" >0.960286</td>
#       <td id="T_3af1c_row5_col1" class="data row5 col1" >0.960816</td>
#       <td id="T_3af1c_row5_col2" class="data row5 col2" >0.960457</td>
#       <td id="T_3af1c_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3af1c_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_3af1c_row6_col0" class="data row6 col0" >0.962501</td>
#       <td id="T_3af1c_row6_col1" class="data row6 col1" >0.962000</td>
#       <td id="T_3af1c_row6_col2" class="data row6 col2" >0.962155</td>
#       <td id="T_3af1c_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[122,   2,   0,   0],
#        [  3, 103,   4,   0],
#        [  0,   5, 116,   4],
#        [  0,   0,   1, 140]], dtype=int64)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier(criterion = 'entropy')
dt_model.fit(X_train,y_train)
y_pred=dt_model.predict(X_test)
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("Results from Decision Tree")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# Accuracy is: 0.86
# Results from Decision Tree
# <style type="text/css">
# #T_afcd7_row0_col0 {
#   background-color: #017267;
#   color: #f1f1f1;
# }
# #T_afcd7_row0_col1 {
#   background-color: #016956;
#   color: #f1f1f1;
# }
# #T_afcd7_row0_col2 {
#   background-color: #016d5c;
#   color: #f1f1f1;
# }
# #T_afcd7_row0_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_afcd7_row1_col0 {
#   background-color: #eae1ef;
#   color: #000000;
# }
# #T_afcd7_row1_col1, #T_afcd7_row1_col2, #T_afcd7_row2_col0, #T_afcd7_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_afcd7_row1_col3 {
#   background-color: #d3d3e7;
#   color: #000000;
# }
# #T_afcd7_row2_col1 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_afcd7_row2_col2 {
#   background-color: #e0daec;
#   color: #000000;
# }
# #T_afcd7_row2_col3 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_afcd7_row3_col0, #T_afcd7_row3_col1, #T_afcd7_row3_col2, #T_afcd7_row5_col3, #T_afcd7_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_afcd7_row3_col3 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_afcd7_row4_col0 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# #T_afcd7_row4_col1, #T_afcd7_row6_col1 {
#   background-color: #4c9bc7;
#   color: #f1f1f1;
# }
# #T_afcd7_row4_col2 {
#   background-color: #5aa2cb;
#   color: #f1f1f1;
# }
# #T_afcd7_row5_col0 {
#   background-color: #6aaad0;
#   color: #f1f1f1;
# }
# #T_afcd7_row5_col1 {
#   background-color: #529ec9;
#   color: #f1f1f1;
# }
# #T_afcd7_row5_col2, #T_afcd7_row6_col0 {
#   background-color: #63a7ce;
#   color: #f1f1f1;
# }
# #T_afcd7_row6_col2 {
#   background-color: #5ba3cb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_afcd7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afcd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afcd7_row0_col0" class="data row0 col0" >0.887097</td>
#       <td id="T_afcd7_row0_col1" class="data row0 col1" >0.909091</td>
#       <td id="T_afcd7_row0_col2" class="data row0 col2" >0.897959</td>
#       <td id="T_afcd7_row0_col3" class="data row0 col3" >121.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afcd7_row1_col0" class="data row1 col0" >0.827273</td>
#       <td id="T_afcd7_row1_col1" class="data row1 col1" >0.771186</td>
#       <td id="T_afcd7_row1_col2" class="data row1 col2" >0.798246</td>
#       <td id="T_afcd7_row1_col3" class="data row1 col3" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afcd7_row2_col0" class="data row2 col0" >0.816000</td>
#       <td id="T_afcd7_row2_col1" class="data row2 col1" >0.822581</td>
#       <td id="T_afcd7_row2_col2" class="data row2 col2" >0.819277</td>
#       <td id="T_afcd7_row2_col3" class="data row2 col3" >124.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afcd7_row3_col0" class="data row3 col0" >0.900709</td>
#       <td id="T_afcd7_row3_col1" class="data row3 col1" >0.927007</td>
#       <td id="T_afcd7_row3_col2" class="data row3 col2" >0.913669</td>
#       <td id="T_afcd7_row3_col3" class="data row3 col3" >137.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_afcd7_row4_col0" class="data row4 col0" >0.860000</td>
#       <td id="T_afcd7_row4_col1" class="data row4 col1" >0.860000</td>
#       <td id="T_afcd7_row4_col2" class="data row4 col2" >0.860000</td>
#       <td id="T_afcd7_row4_col3" class="data row4 col3" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_afcd7_row5_col0" class="data row5 col0" >0.857770</td>
#       <td id="T_afcd7_row5_col1" class="data row5 col1" >0.857466</td>
#       <td id="T_afcd7_row5_col2" class="data row5 col2" >0.857288</td>
#       <td id="T_afcd7_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afcd7_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_afcd7_row6_col0" class="data row6 col0" >0.859076</td>
#       <td id="T_afcd7_row6_col1" class="data row6 col1" >0.860000</td>
#       <td id="T_afcd7_row6_col2" class="data row6 col2" >0.859218</td>
#       <td id="T_afcd7_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
confusion_matrix(y_test, y_pred )
# Out:
# array([[110,  14,   0,   0],
#        [ 11,  91,   8,   0],
#        [  0,  13, 102,  10],
#        [  0,   0,  14, 127]], dtype=int64)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=300)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
y_pred = rf_model.predict(X_test)
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("Results from RandomForest Classifier")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# Accuracy is: 0.87
# Results from RandomForest Classifier
# <style type="text/css">
# #T_48cc1_row0_col0, #T_48cc1_row0_col1, #T_48cc1_row0_col2, #T_48cc1_row5_col3, #T_48cc1_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_48cc1_row0_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_48cc1_row1_col0 {
#   background-color: #dcd8ea;
#   color: #000000;
# }
# #T_48cc1_row1_col1 {
#   background-color: #f5ecf5;
#   color: #000000;
# }
# #T_48cc1_row1_col2 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_48cc1_row1_col3 {
#   background-color: #d8d6e9;
#   color: #000000;
# }
# #T_48cc1_row2_col0, #T_48cc1_row2_col1, #T_48cc1_row2_col2, #T_48cc1_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_48cc1_row2_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_48cc1_row3_col0 {
#   background-color: #14869d;
#   color: #f1f1f1;
# }
# #T_48cc1_row3_col1 {
#   background-color: #015b4a;
#   color: #f1f1f1;
# }
# #T_48cc1_row3_col2 {
#   background-color: #027978;
#   color: #f1f1f1;
# }
# #T_48cc1_row3_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_48cc1_row4_col0 {
#   background-color: #6cabd0;
#   color: #f1f1f1;
# }
# #T_48cc1_row4_col1, #T_48cc1_row6_col1 {
#   background-color: #58a2cb;
#   color: #f1f1f1;
# }
# #T_48cc1_row4_col2 {
#   background-color: #63a7ce;
#   color: #f1f1f1;
# }
# #T_48cc1_row5_col0 {
#   background-color: #74add1;
#   color: #f1f1f1;
# }
# #T_48cc1_row5_col1 {
#   background-color: #68a9cf;
#   color: #f1f1f1;
# }
# #T_48cc1_row5_col2 {
#   background-color: #6eabd0;
#   color: #f1f1f1;
# }
# #T_48cc1_row6_col0 {
#   background-color: #66a9cf;
#   color: #f1f1f1;
# }
# #T_48cc1_row6_col2 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_48cc1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48cc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48cc1_row0_col0" class="data row0 col0" >0.975806</td>
#       <td id="T_48cc1_row0_col1" class="data row0 col1" >0.930769</td>
#       <td id="T_48cc1_row0_col2" class="data row0 col2" >0.952756</td>
#       <td id="T_48cc1_row0_col3" class="data row0 col3" >130.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48cc1_row1_col0" class="data row1 col0" >0.809091</td>
#       <td id="T_48cc1_row1_col1" class="data row1 col1" >0.809091</td>
#       <td id="T_48cc1_row1_col2" class="data row1 col2" >0.809091</td>
#       <td id="T_48cc1_row1_col3" class="data row1 col3" >110.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48cc1_row2_col0" class="data row2 col0" >0.768000</td>
#       <td id="T_48cc1_row2_col1" class="data row2 col1" >0.800000</td>
#       <td id="T_48cc1_row2_col2" class="data row2 col2" >0.783673</td>
#       <td id="T_48cc1_row2_col3" class="data row2 col3" >120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48cc1_row3_col0" class="data row3 col0" >0.914894</td>
#       <td id="T_48cc1_row3_col1" class="data row3 col1" >0.921429</td>
#       <td id="T_48cc1_row3_col2" class="data row3 col2" >0.918149</td>
#       <td id="T_48cc1_row3_col3" class="data row3 col3" >140.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_48cc1_row4_col0" class="data row4 col0" >0.870000</td>
#       <td id="T_48cc1_row4_col1" class="data row4 col1" >0.870000</td>
#       <td id="T_48cc1_row4_col2" class="data row4 col2" >0.870000</td>
#       <td id="T_48cc1_row4_col3" class="data row4 col3" >0.870000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_48cc1_row5_col0" class="data row5 col0" >0.866948</td>
#       <td id="T_48cc1_row5_col1" class="data row5 col1" >0.865322</td>
#       <td id="T_48cc1_row5_col2" class="data row5 col2" >0.865917</td>
#       <td id="T_48cc1_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48cc1_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_48cc1_row6_col0" class="data row6 col0" >0.872200</td>
#       <td id="T_48cc1_row6_col1" class="data row6 col1" >0.870000</td>
#       <td id="T_48cc1_row6_col2" class="data row6 col2" >0.870880</td>
#       <td id="T_48cc1_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[121,   3,   0,   0],
#        [  9,  89,  12,   0],
#        [  0,  18,  96,  11],
#        [  0,   0,  12, 129]], dtype=int64)

# %% [markdown]
# # K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values = [] 
neighbors = np.arange(3,15)
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k,metric = 'minkowski')
    classifier.fit(X_train,y_train)
    y_pred = classifier.predict(X_test)
    acc = accuracy_score(y_test,y_pred)
    acc_values.append(acc)
print(acc_values)
# Out:
# [0.482, 0.512, 0.506, 0.514, 0.506, 0.53, 0.546, 0.556, 0.538, 0.558, 0.574, 0.59]

# %%
plt.plot(neighbors,acc_values, 'o-')
plt.xlabel('k value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
classifier = KNeighborsClassifier(n_neighbors = 14,metric = 'minkowski')
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)
from sklearn.metrics import accuracy_score,confusion_matrix
print('accuracy score is :',accuracy_score(y_test,y_pred))
print("Results from K-NN")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# accuracy score is : 0.59
# Results from K-NN
# <style type="text/css">
# #T_0332c_row0_col0, #T_0332c_row0_col2, #T_0332c_row3_col1, #T_0332c_row5_col3, #T_0332c_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_0332c_row0_col1 {
#   background-color: #028189;
#   color: #f1f1f1;
# }
# #T_0332c_row0_col3 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_0332c_row1_col0, #T_0332c_row3_col3 {
#   background-color: #dad7ea;
#   color: #000000;
# }
# #T_0332c_row1_col1, #T_0332c_row1_col2, #T_0332c_row2_col0, #T_0332c_row2_col2, #T_0332c_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_0332c_row1_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_0332c_row2_col1 {
#   background-color: #f1e8f3;
#   color: #000000;
# }
# #T_0332c_row2_col3 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_0332c_row3_col0 {
#   background-color: #70acd1;
#   color: #f1f1f1;
# }
# #T_0332c_row3_col2 {
#   background-color: #016956;
#   color: #f1f1f1;
# }
# #T_0332c_row4_col0 {
#   background-color: #8cb5d6;
#   color: #000000;
# }
# #T_0332c_row4_col1, #T_0332c_row6_col1 {
#   background-color: #91b6d7;
#   color: #000000;
# }
# #T_0332c_row4_col2 {
#   background-color: #78aed2;
#   color: #f1f1f1;
# }
# #T_0332c_row5_col0 {
#   background-color: #90b6d7;
#   color: #000000;
# }
# #T_0332c_row5_col1 {
#   background-color: #7aafd3;
#   color: #f1f1f1;
# }
# #T_0332c_row5_col2 {
#   background-color: #76aed2;
#   color: #f1f1f1;
# }
# #T_0332c_row6_col0 {
#   background-color: #97b8d8;
#   color: #000000;
# }
# #T_0332c_row6_col2 {
#   background-color: #8ab4d6;
#   color: #000000;
# }
# </style>
# <table id="T_0332c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0332c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0332c_row0_col0" class="data row0 col0" >0.725806</td>
#       <td id="T_0332c_row0_col1" class="data row0 col1" >0.725806</td>
#       <td id="T_0332c_row0_col2" class="data row0 col2" >0.725806</td>
#       <td id="T_0332c_row0_col3" class="data row0 col3" >124.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0332c_row1_col0" class="data row1 col0" >0.536364</td>
#       <td id="T_0332c_row1_col1" class="data row1 col1" >0.421429</td>
#       <td id="T_0332c_row1_col2" class="data row1 col2" >0.472000</td>
#       <td id="T_0332c_row1_col3" class="data row1 col3" >140.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0332c_row2_col0" class="data row2 col0" >0.488000</td>
#       <td id="T_0332c_row2_col1" class="data row2 col1" >0.458647</td>
#       <td id="T_0332c_row2_col2" class="data row2 col2" >0.472868</td>
#       <td id="T_0332c_row2_col3" class="data row2 col3" >133.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0332c_row3_col0" class="data row3 col0" >0.602837</td>
#       <td id="T_0332c_row3_col1" class="data row3 col1" >0.825243</td>
#       <td id="T_0332c_row3_col2" class="data row3 col2" >0.696721</td>
#       <td id="T_0332c_row3_col3" class="data row3 col3" >103.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_0332c_row4_col0" class="data row4 col0" >0.590000</td>
#       <td id="T_0332c_row4_col1" class="data row4 col1" >0.590000</td>
#       <td id="T_0332c_row4_col2" class="data row4 col2" >0.590000</td>
#       <td id="T_0332c_row4_col3" class="data row4 col3" >0.590000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_0332c_row5_col0" class="data row5 col0" >0.588252</td>
#       <td id="T_0332c_row5_col1" class="data row5 col1" >0.607781</td>
#       <td id="T_0332c_row5_col2" class="data row5 col2" >0.591849</td>
#       <td id="T_0332c_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0332c_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_0332c_row6_col0" class="data row6 col0" >0.584174</td>
#       <td id="T_0332c_row6_col1" class="data row6 col1" >0.590000</td>
#       <td id="T_0332c_row6_col2" class="data row6 col2" >0.581468</td>
#       <td id="T_0332c_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[90, 30,  4,  0],
#        [27, 59, 21,  3],
#        [ 7, 42, 61, 15],
#        [ 0,  9, 47, 85]], dtype=int64)

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC=GradientBoostingClassifier()
GBC.fit(X_train,y_train)
y_pred=GBC.predict(X_test)
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("Results from Gradient boosting classifier")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# Accuracy is: 0.922
# Results from Gradient boosting classifier
# <style type="text/css">
# #T_aec3a_row0_col0, #T_aec3a_row0_col1, #T_aec3a_row0_col2, #T_aec3a_row5_col3, #T_aec3a_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_aec3a_row0_col3 {
#   background-color: #d1d1e6;
#   color: #000000;
# }
# #T_aec3a_row1_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_aec3a_row1_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_aec3a_row1_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_aec3a_row1_col3 {
#   background-color: #d7d5e8;
#   color: #000000;
# }
# #T_aec3a_row2_col0, #T_aec3a_row2_col1, #T_aec3a_row2_col2, #T_aec3a_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_aec3a_row2_col3 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_aec3a_row3_col0 {
#   background-color: #549fc9;
#   color: #f1f1f1;
# }
# #T_aec3a_row3_col1 {
#   background-color: #1887a0;
#   color: #f1f1f1;
# }
# #T_aec3a_row3_col2 {
#   background-color: #3590bf;
#   color: #f1f1f1;
# }
# #T_aec3a_row3_col3 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_aec3a_row4_col0 {
#   background-color: #70acd1;
#   color: #f1f1f1;
# }
# #T_aec3a_row4_col1, #T_aec3a_row6_col1 {
#   background-color: #62a6cd;
#   color: #f1f1f1;
# }
# #T_aec3a_row4_col2, #T_aec3a_row6_col2 {
#   background-color: #68a9cf;
#   color: #f1f1f1;
# }
# #T_aec3a_row5_col0, #T_aec3a_row6_col0 {
#   background-color: #72acd1;
#   color: #f1f1f1;
# }
# #T_aec3a_row5_col1 {
#   background-color: #65a8ce;
#   color: #f1f1f1;
# }
# #T_aec3a_row5_col2 {
#   background-color: #6cabd0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aec3a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aec3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aec3a_row0_col0" class="data row0 col0" >0.975806</td>
#       <td id="T_aec3a_row0_col1" class="data row0 col1" >0.975806</td>
#       <td id="T_aec3a_row0_col2" class="data row0 col2" >0.975806</td>
#       <td id="T_aec3a_row0_col3" class="data row0 col3" >124.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aec3a_row1_col0" class="data row1 col0" >0.909091</td>
#       <td id="T_aec3a_row1_col1" class="data row1 col1" >0.900901</td>
#       <td id="T_aec3a_row1_col2" class="data row1 col2" >0.904977</td>
#       <td id="T_aec3a_row1_col3" class="data row1 col3" >111.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aec3a_row2_col0" class="data row2 col0" >0.872000</td>
#       <td id="T_aec3a_row2_col1" class="data row2 col1" >0.865079</td>
#       <td id="T_aec3a_row2_col2" class="data row2 col2" >0.868526</td>
#       <td id="T_aec3a_row2_col3" class="data row2 col3" >126.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aec3a_row3_col0" class="data row3 col0" >0.929078</td>
#       <td id="T_aec3a_row3_col1" class="data row3 col1" >0.942446</td>
#       <td id="T_aec3a_row3_col2" class="data row3 col2" >0.935714</td>
#       <td id="T_aec3a_row3_col3" class="data row3 col3" >139.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_aec3a_row4_col0" class="data row4 col0" >0.922000</td>
#       <td id="T_aec3a_row4_col1" class="data row4 col1" >0.922000</td>
#       <td id="T_aec3a_row4_col2" class="data row4 col2" >0.922000</td>
#       <td id="T_aec3a_row4_col3" class="data row4 col3" >0.922000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_aec3a_row5_col0" class="data row5 col0" >0.921494</td>
#       <td id="T_aec3a_row5_col1" class="data row5 col1" >0.921058</td>
#       <td id="T_aec3a_row5_col2" class="data row5 col2" >0.921256</td>
#       <td id="T_aec3a_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aec3a_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_aec3a_row6_col0" class="data row6 col0" >0.921846</td>
#       <td id="T_aec3a_row6_col1" class="data row6 col1" >0.922000</td>
#       <td id="T_aec3a_row6_col2" class="data row6 col2" >0.921902</td>
#       <td id="T_aec3a_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[121   3   0   0]
#  [  3 100   7   0]
#  [  0   8 109   8]
#  [  0   0  10 131]]

# %% [markdown]
# # XGBoost Classifier

# %%
from xgboost import XGBClassifier
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("Results from XG Boost classifier")
result = classification_report(y_pred,y_test,output_dict=True)
result = pd.DataFrame(result).transpose()
result.style.background_gradient(cmap="PuBuGn")
# Out:
# Accuracy is: 0.918
# Results from XG Boost classifier
# <style type="text/css">
# #T_425ca_row0_col0, #T_425ca_row0_col1, #T_425ca_row0_col2, #T_425ca_row5_col3, #T_425ca_row6_col3 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_425ca_row0_col3, #T_425ca_row1_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_425ca_row1_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_425ca_row1_col1 {
#   background-color: #fdf4fa;
#   color: #000000;
# }
# #T_425ca_row1_col3 {
#   background-color: #d8d6e9;
#   color: #000000;
# }
# #T_425ca_row2_col0, #T_425ca_row2_col1, #T_425ca_row2_col2, #T_425ca_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_425ca_row2_col3 {
#   background-color: #d3d3e7;
#   color: #000000;
# }
# #T_425ca_row3_col0 {
#   background-color: #027e83;
#   color: #f1f1f1;
# }
# #T_425ca_row3_col1 {
#   background-color: #2e8eb8;
#   color: #f1f1f1;
# }
# #T_425ca_row3_col2 {
#   background-color: #098391;
#   color: #f1f1f1;
# }
# #T_425ca_row3_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_425ca_row4_col0 {
#   background-color: #57a1ca;
#   color: #f1f1f1;
# }
# #T_425ca_row4_col1, #T_425ca_row6_col1 {
#   background-color: #84b2d4;
#   color: #000000;
# }
# #T_425ca_row4_col2 {
#   background-color: #60a5cd;
#   color: #f1f1f1;
# }
# #T_425ca_row5_col0 {
#   background-color: #5ba3cb;
#   color: #f1f1f1;
# }
# #T_425ca_row5_col1 {
#   background-color: #91b6d7;
#   color: #000000;
# }
# #T_425ca_row5_col2 {
#   background-color: #68a9cf;
#   color: #f1f1f1;
# }
# #T_425ca_row6_col0 {
#   background-color: #519ec8;
#   color: #f1f1f1;
# }
# #T_425ca_row6_col2 {
#   background-color: #5fa5cc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_425ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >precision</th>
#       <th class="col_heading level0 col1" >recall</th>
#       <th class="col_heading level0 col2" >f1-score</th>
#       <th class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_425ca_row0_col0" class="data row0 col0" >0.983871</td>
#       <td id="T_425ca_row0_col1" class="data row0 col1" >0.953125</td>
#       <td id="T_425ca_row0_col2" class="data row0 col2" >0.968254</td>
#       <td id="T_425ca_row0_col3" class="data row0 col3" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_425ca_row1_col0" class="data row1 col0" >0.890909</td>
#       <td id="T_425ca_row1_col1" class="data row1 col1" >0.890909</td>
#       <td id="T_425ca_row1_col2" class="data row1 col2" >0.890909</td>
#       <td id="T_425ca_row1_col3" class="data row1 col3" >110.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_425ca_row2_col0" class="data row2 col0" >0.840000</td>
#       <td id="T_425ca_row2_col1" class="data row2 col1" >0.889831</td>
#       <td id="T_425ca_row2_col2" class="data row2 col2" >0.864198</td>
#       <td id="T_425ca_row2_col3" class="data row2 col3" >118.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_425ca_row3_col0" class="data row3 col0" >0.950355</td>
#       <td id="T_425ca_row3_col1" class="data row3 col1" >0.930556</td>
#       <td id="T_425ca_row3_col2" class="data row3 col2" >0.940351</td>
#       <td id="T_425ca_row3_col3" class="data row3 col3" >144.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row4" class="row_heading level0 row4" >accuracy</th>
#       <td id="T_425ca_row4_col0" class="data row4 col0" >0.918000</td>
#       <td id="T_425ca_row4_col1" class="data row4 col1" >0.918000</td>
#       <td id="T_425ca_row4_col2" class="data row4 col2" >0.918000</td>
#       <td id="T_425ca_row4_col3" class="data row4 col3" >0.918000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row5" class="row_heading level0 row5" >macro avg</th>
#       <td id="T_425ca_row5_col0" class="data row5 col0" >0.916284</td>
#       <td id="T_425ca_row5_col1" class="data row5 col1" >0.916105</td>
#       <td id="T_425ca_row5_col2" class="data row5 col2" >0.915928</td>
#       <td id="T_425ca_row5_col3" class="data row5 col3" >500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_425ca_level0_row6" class="row_heading level0 row6" >weighted avg</th>
#       <td id="T_425ca_row6_col0" class="data row6 col0" >0.919813</td>
#       <td id="T_425ca_row6_col1" class="data row6 col1" >0.918000</td>
#       <td id="T_425ca_row6_col2" class="data row6 col2" >0.918645</td>
#       <td id="T_425ca_row6_col3" class="data row6 col3" >500.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[122   2   0   0]
#  [  3 103   4   0]
#  [  0   5 116   4]
#  [  0   0   1 140]]

# %% [markdown]
# # Test dataset to predict the results

# %%
df_test = pd.read_csv('MobileTest.csv',index_col='id')

# %%
df_test.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
#
#     mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id
# 1         193        3  16        226      1412  3476    12     7          2
# 2         191        5  12        746       857  3895     6     0          7
# 3         186        3   4       1270      1366  2396    17    10         10
# 4          96        8  20        295      1752  3893    10     0          7
# 5         108        6  18        749       810  1773    15     8          7
#
#     three_g  touch_screen  wifi
# id
# 1         0             1     0
# 2         1             0     0
# 3         0             1     1
# 4         1             1     0
# 5         1             0     1

# %%
df_test_scaled=scaler.fit_transform(df_test)
df_test_scaled
# Out:
# array([[-0.47545131,  0.968496  ,  0.31260069, ..., -1.76021608,
#          1.        , -1.01409939],
#        [-0.94278218,  0.968496  , -1.25583195, ...,  0.56811207,
#         -1.        , -1.01409939],
#        [ 1.29207729,  0.968496  ,  1.51908734, ..., -1.76021608,
#          1.        ,  0.98609664],
#        ...,
#        [-0.1469316 , -1.03252879, -0.16999397, ...,  0.56811207,
#         -1.        , -1.01409939],
#        [ 0.65817305,  0.968496  , -1.25583195, ..., -1.76021608,
#          1.        , -1.01409939],
#        [ 0.04971753,  0.968496  , -1.25583195, ...,  0.56811207,
#         -1.        ,  0.98609664]])

# %%
test_pred=logit_model.predict(df_test_scaled)

# %%
result=pd.DataFrame(test_pred)

# %%
print(result)
# Out:
#      0
# 0    2
# 1    3
# 2    2
# 3    3
# 4    1
# ..  ..
# 995  2
# 996  1
# 997  0
# 998  2
# 999  2
#
# [1000 rows x 1 columns]

# %%
pd.DataFrame(result).to_csv('result.csv')

# %% [markdown]
# # Ranking of features of smartphone

# %%
#Ranking dataset according to price range

df_train["rank_by_price"]=df_train["price_range"].rank()
df1=df_train
df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2   2         20       756  2549     9     7
# 1       0.7        136        3   6        905      1988  2631    17     3
# 2       0.9        145        5   6       1263      1716  2603    11     2
# 3       0.8        131        6   9       1216      1786  2769    16     8
# 4       0.6        141        2  14       1208      1212  1411     8     2
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range  rank_by_price
# 0            19        0             0     1            1          750.5
# 1             7        1             1     0            2         1250.5
# 2             9        1             1     0            2         1250.5
# 3            11        1             0     0            2         1250.5
# 4            15        1             1     0            1          750.5
# ...         ...      ...           ...   ...          ...            ...
# 1995         19        1             1     0            0          250.5
# 1996         16        1             1     1            2         1250.5
# 1997          5        1             1     0            3         1750.5
# 1998         19        1             1     1            0          250.5
# 1999          2        1             1     1            3         1750.5
#
# [2000 rows x 22 columns]

# %%
df1["rank_by_price"]=df1["rank_by_price"].sort_values()
df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2   2         20       756  2549     9     7
# 1       0.7        136        3   6        905      1988  2631    17     3
# 2       0.9        145        5   6       1263      1716  2603    11     2
# 3       0.8        131        6   9       1216      1786  2769    16     8
# 4       0.6        141        2  14       1208      1212  1411     8     2
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range  rank_by_price
# 0            19        0             0     1            1          750.5
# 1             7        1             1     0            2         1250.5
# 2             9        1             1     0            2         1250.5
# 3            11        1             0     0            2         1250.5
# 4            15        1             1     0            1          750.5
# ...         ...      ...           ...   ...          ...            ...
# 1995         19        1             1     0            0          250.5
# 1996         16        1             1     1            2         1250.5
# 1997          5        1             1     0            3         1750.5
# 1998         19        1             1     1            0          250.5
# 1999          2        1             1     1            3         1750.5
#
# [2000 rows x 22 columns]

# %%
#Sorting above dataset according to ranked_price_range

df1.sort_values(by=["rank_by_price"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1838    0.8        165        4  14        366      1234  1086    14     7
# 1762    0.5        105        8  15        119       529  1082    15     5
# 419     0.8        100        2  12        191      1495   808    11     7
# 846     0.6        200        1  16        172       812   776     7     6
# 845     0.9        105        7  15        713      1513   286    14     4
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 981     0.2        100        8   0        259      1040  3863    17    12
# 982     0.5         99        3   3        236      1960  3506    14     5
# 987     0.2        170        7   0        650       864  3984    17    14
# 956     0.1        107        8  14        829      1977  3458     9     4
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range  rank_by_price
# 1838          3        1             1     0            0          250.5
# 1762         10        1             0     1            0          250.5
# 419           5        1             1     0            0          250.5
# 846           8        0             0     0            0          250.5
# 845          17        1             0     1            0          250.5
# ...         ...      ...           ...   ...          ...            ...
# 981           9        1             1     1            3         1750.5
# 982          12        1             1     0            3         1750.5
# 987           8        1             1     1            3         1750.5
# 956           9        1             1     1            3         1750.5
# 1999          2        1             1     1            3         1750.5
#
# [2000 rows x 22 columns]

# %%
#Ranking on all the features using rank()

RankedData = df1.rank()
RankedData.sort_values(by="price_range")
# Out:
#       battery_power    blue  clock_speed  dual_sim      fc  four_g  \
# 1838          320.5  1505.5        638.5    1491.0  1853.0  1479.0
# 1762          435.5  1505.5        207.0    1491.0   993.5   479.0
# 419           589.0  1505.5        638.5     491.0   814.0   479.0
# 846          1323.5   505.5       1612.5    1491.0  1601.0   479.0
# 845          1875.0   505.5       1337.0     491.0  1895.5   479.0
# ...             ...     ...          ...       ...     ...     ...
# 981           753.0  1505.5       1868.0    1491.0   237.5  1479.0
# 982           737.5   505.5        450.5    1491.0   814.0  1479.0
# 987          1583.0   505.5       1678.5     491.0   237.5  1479.0
# 956           515.5   505.5       1544.5     491.0  1678.5  1479.0
# 1999           21.0  1505.5       1337.0    1491.0  1281.0  1479.0
#
#       int_memory   m_dep  mobile_wt  n_cores      pc  px_height  px_width  \
# 1838       432.0  1595.5     1414.5    872.5  1394.5      657.5     978.0
# 1762      1451.5  1003.0      436.0   1872.5  1492.5      189.0      45.0
# 419         77.5  1595.5      325.5    366.0  1212.5      329.5    1341.0
# 846       1011.0  1198.5     1991.0    121.5  1582.5      288.0     408.0
# 845       1727.0  1797.0      436.0   1615.0  1492.5     1231.5    1363.0
# ...          ...     ...        ...      ...     ...        ...       ...
# 981       1828.5   427.0      325.5   1872.5    51.0      455.0     728.0
# 982       1382.0  1003.0      309.0    612.5   351.0      419.5    1937.0
# 987        669.5   427.0     1496.0   1615.0    51.0     1134.0     481.5
# 956        142.0   160.5      472.5   1872.5  1394.5     1371.0    1966.0
# 1999      1418.0  1797.0     1457.5   1370.5  1582.5      868.0     331.5
#
#          ram    sc_h    sc_w  talk_time  three_g  touch_screen    wifi  \
# 1838   445.5  1214.0  1284.5      146.5   1239.0        1497.5   493.5
# 1762   442.0  1353.0  1008.0      901.0   1239.0         497.5  1493.5
# 419    306.0   791.5  1284.5      363.0   1239.0        1497.5   493.5
# 846    292.0   287.0  1153.5      696.5    239.0         497.5   493.5
# 845     16.0  1214.0   836.5     1636.5   1239.0         497.5  1493.5
# ...      ...     ...     ...        ...      ...           ...     ...
# 981   1919.0  1660.0  1797.5      798.5   1239.0        1497.5  1493.5
# 982   1732.0  1214.0  1008.0     1106.0   1239.0        1497.5   493.5
# 987   1994.0  1660.0  1897.0      696.5   1239.0        1497.5  1493.5
# 956   1703.5   541.5   836.5      798.5   1239.0        1497.5  1493.5
# 1999  1959.0  1938.5   836.5       50.0   1239.0        1497.5  1493.5
#
#       price_range  rank_by_price
# 1838        250.5          250.5
# 1762        250.5          250.5
# 419         250.5          250.5
# 846         250.5          250.5
# 845         250.5          250.5
# ...           ...            ...
# 981        1750.5         1750.5
# 982        1750.5         1750.5
# 987        1750.5         1750.5
# 956        1750.5         1750.5
# 1999       1750.5         1750.5
#
# [2000 rows x 22 columns]

# %%
#Ranking all the features separately to correct output
#Because not all features are good when values are high or low
#It depends on each and every feature.
r= df1
r["rank_by_price"] = r["price_range"].rank()
r["rank_by_battery"] = r["battery_power"].rank(ascending=False)
r["rank_by_blueooth"] = r["blue"].rank(ascending=False)
r["rank_by_clockspeed"] = r["clock_speed"].rank(ascending=False)
r["rank_by_DualSIM"] = r["dual_sim"].rank(ascending=False)
r["rank_by_fc"] = r["fc"].rank(ascending=False)
r["rank_by_4G"] = r["four_g"].rank(ascending=False)
r["rank_by_InternalMemory"] = r["int_memory"].rank(ascending=False)
r["rank_by_mdep"] = r["m_dep"].rank(ascending=False)
r["rank_by_weight"] = r["mobile_wt"].rank(ascending=True)
r["rank_by_ncores"] = r["n_cores"].rank(ascending=False)
r["rank_by_pc"] = r["pc"].rank(ascending=False)
r["rank_by_height"] = r["px_height"].rank(ascending=False)
r["rank_by_width"] = r["px_width"].rank(ascending=False)
r["rank_by_ram"] = r["ram"].rank(ascending=False)
r["rank_by_sch"] = r["sc_h"].rank(ascending=False)
r["rank_by_scw"] = r["sc_w"].rank(ascending=False)
r["rank_by_talktime"] = r["talk_time"].rank(ascending=False)
r["rank_by_3G"] = r["three_g"].rank(ascending=False)
r["rank_by_touchscreen"] = r["touch_screen"].rank(ascending=False)
r["rank_by_wifi"] = r["wifi"].rank(ascending=False)
r.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range  rank_by_price  rank_by_battery  \
# 0        0             0     1            1          750.5           1512.5
# 1        1             1     0            2         1250.5           1278.5
# 2        1             1     0            2         1250.5           1909.5
# 3        1             0     0            2         1250.5           1830.0
# 4        1             1     0            1          750.5            242.0
#
#    rank_by_blueooth  rank_by_clockspeed  rank_by_DualSIM  rank_by_fc  \
# 0            1495.5               525.0           1510.0      1404.0
# 1             495.5              1794.0            510.0      1763.5
# 2             495.5              1794.0            510.0      1187.0
# 3             495.5               322.5           1510.0      1763.5
# 4             495.5              1193.5           1510.0       105.5
#
#    rank_by_4G  rank_by_InternalMemory  rank_by_mdep  rank_by_weight  \
# 0      1522.0                  1820.5         802.5          1783.5
# 1       522.0                   334.5         609.5           932.5
# 2       522.0                   720.0         204.0          1069.0
# 3      1522.0                  1710.5         405.5           846.0
# 4       522.0                   619.0         802.5          1006.0
#
#    rank_by_ncores  rank_by_pc  rank_by_height  rank_by_width  rank_by_ram  \
# 0          1635.0      1746.0          1972.5         1664.5        762.5
# 1          1388.5      1402.0           545.5           17.0        714.0
# 2           868.5      1402.0           212.0          386.5        732.0
# 3           630.5      1090.5           250.0          287.0        639.0
# 4          1635.0       606.5           261.5         1054.0       1375.0
#
#    rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# 0       1459.5        716.5             159.0      1762.0
# 1        341.0       1355.0            1418.5       762.0
# 2       1209.5       1532.5            1202.5       762.0
# 3        509.0        588.0             996.0       762.0
# 4       1580.0       1532.5             587.0       762.0
#
#    rank_by_touchscreen  rank_by_wifi
# 0               1503.5         507.5
# 1                503.5        1507.5
# 2                503.5        1507.5
# 3               1503.5        1507.5
# 4                503.5        1507.5

# %%
RankedData = r.iloc[:,21:]
RankedData
# Out:
#       rank_by_price  rank_by_battery  rank_by_blueooth  rank_by_clockspeed  \
# 0             750.5           1512.5            1495.5               525.0
# 1            1250.5           1278.5             495.5              1794.0
# 2            1250.5           1909.5             495.5              1794.0
# 3            1250.5           1830.0             495.5               322.5
# 4             750.5            242.0             495.5              1193.5
# ...             ...              ...               ...                 ...
# 1995          250.5           1587.5             495.5              1794.0
# 1996         1250.5             58.0             495.5               258.0
# 1997         1750.5            121.5            1495.5              1362.5
# 1998          250.5            648.0            1495.5              1362.5
# 1999         1750.5           1980.0             495.5               664.0
#
#       rank_by_DualSIM  rank_by_fc  rank_by_4G  rank_by_InternalMemory  \
# 0              1510.0      1404.0      1522.0                  1820.5
# 1               510.0      1763.5       522.0                   334.5
# 2               510.0      1187.0       522.0                   720.0
# 3              1510.0      1763.5      1522.0                  1710.5
# 4              1510.0       105.5       522.0                   619.0
# ...               ...         ...         ...                     ...
# 1995            510.0      1763.5       522.0                  1979.5
# 1996            510.0      1763.5      1522.0                   784.5
# 1997            510.0      1404.0       522.0                   860.0
# 1998           1510.0       856.0       522.0                   549.5
# 1999            510.0       720.0       522.0                   583.0
#
#       rank_by_mdep  rank_by_weight  rank_by_ncores  rank_by_pc  \
# 0            802.5          1783.5          1635.0      1746.0
# 1            609.5           932.5          1388.5      1402.0
# 2            204.0          1069.0           868.5      1402.0
# 3            405.5           846.0           630.5      1090.5
# 4            802.5          1006.0          1635.0       606.5
# ...            ...             ...             ...         ...
# 1995         405.5           456.0           630.5       606.5
# 1996        1574.0          1766.5          1128.5      1650.0
# 1997         609.5           486.5           128.5      1650.0
# 1998        1840.5          1069.0           868.5      1479.0
# 1999         204.0          1457.5           630.5       418.5
#
#       rank_by_height  rank_by_width  rank_by_ram  rank_by_sch  rank_by_scw  \
# 0             1972.5         1664.5        762.5       1459.5        716.5
# 1              545.5           17.0        714.0        341.0       1355.0
# 2              212.0          386.5        732.0       1209.5       1532.5
# 3              250.0          287.0        639.0        509.0        588.0
# 4              261.5         1054.0       1375.0       1580.0       1532.5
# ...              ...            ...          ...          ...          ...
# 1995           244.5          163.0       1767.0        924.0       1164.5
# 1996           536.0           54.5       1062.0       1209.5        375.0
# 1997           583.5          502.0        504.0       1459.5       1715.5
# 1998          1395.5         1792.5       1664.5        184.5        375.0
# 1999          1133.0         1669.5         42.0         62.5       1164.5
#
#       rank_by_talktime  rank_by_3G  rank_by_touchscreen  rank_by_wifi
# 0                159.0      1762.0               1503.5         507.5
# 1               1418.5       762.0                503.5        1507.5
# 2               1202.5       762.0                503.5        1507.5
# 3                996.0       762.0               1503.5        1507.5
# 4                587.0       762.0                503.5        1507.5
# ...                ...         ...                  ...           ...
# 1995             159.0       762.0                503.5        1507.5
# 1996             471.5       762.0                503.5         507.5
# 1997            1638.0       762.0                503.5        1507.5
# 1998             159.0       762.0                503.5         507.5
# 1999            1951.0       762.0                503.5         507.5
#
# [2000 rows x 21 columns]
